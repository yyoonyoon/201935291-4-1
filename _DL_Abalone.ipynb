# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

col_names = ['sex', 'length', 'diameter', 'height', 'whole_weight', 'shucked_weight', 'viscera_weight', 'shell_weight','rings']
df = pd.read_csv("/Users/yeomsangyoon/Visual Studio/0_tensor/source/abalone.csv", header=None, names= col_names)
df
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       viscera_weight  shell_weight  rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.columns
# Out:
# Index(['sex', 'length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#        'viscera_weight', 'shell_weight', 'rings'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#-----------------------------------------------------
# sex 레이블 개수 확인 (숫자)
print("sex label count:")
print(df['sex'].value_counts(), "\n")
# sex 레이블 개수 확인 (그래프)
plt.figure(figsize=(4, 3))
sns.countplot(data=df, x="sex")
plt.xlabel("sex")
plt.title("Abalon - sex")
plt.show()
# sex subject 개수 확인
sex_subject_count = df['sex'].nunique()
print("sex Subject Count:", sex_subject_count)
print()
# Out:
# sex label count:
# sex
# M    1528
# I    1342
# F    1307
# Name: count, dtype: int64
# sex Subject Count: 3

# %%
# length 레이블 개수 확인 (숫자)
print("length label count:")
print(df['length'].value_counts(), "\n")
# length 레이블 개수 확인 (그래프)
plt.figure(figsize=(80, 10))
sns.countplot(data=df, x="length")
plt.xlabel("length")
plt.title("Abalone - length")
plt.show()
# length subject 개수 확인
length_subject_count = df['length'].nunique()
print("length Subject Count:", length_subject_count)
# Out:
# length label count:
# length
# 0.625    94
# 0.550    94
# 0.575    93
# 0.580    92
# 0.600    87
#          ..
# 0.075     1
# 0.815     1
# 0.110     1
# 0.150     1
# 0.800     1
# Name: count, Length: 134, dtype: int64
# length Subject Count: 134

# %%
# diameter 레이블 개수 확인 (숫자)
print("diameter label count:")
print(df['diameter'].value_counts(), "\n")
# diameter 레이블 개수 확인 (그래프)
plt.figure(figsize=(60, 10))
sns.countplot(data=df, x="diameter")
plt.xlabel("diameter")
plt.title("Abalone - diameter")
plt.show()
# length subject 개수 확인
diameter_subject_count = df['diameter'].nunique()
print("diameter Subject Count:", diameter_subject_count)
# Out:
# diameter label count:
# diameter
# 0.450    139
# 0.475    120
# 0.400    111
# 0.500    110
# 0.470    100
#         ...
# 0.610      1
# 0.650      1
# 0.620      1
# 0.095      1
# 0.615      1
# Name: count, Length: 111, dtype: int64
# diameter Subject Count: 111

# %%
# height 레이블 개수 확인 (숫자)
print("height label count:")
print(df['height'].value_counts(), "\n")
# height 레이블 개수 확인 (그래프)
plt.figure(figsize=(40, 10))
sns.countplot(data=df, x="height")
plt.xlabel("height")
plt.title("Abalone - height")
plt.show()
# height subject 개수 확인
height_subject_count = df['height'].nunique()
print("height Subject Count:", height_subject_count)
# Out:
# height label count:
# height
# 0.150    267
# 0.140    220
# 0.155    217
# 0.175    211
# 0.160    205
# 0.125    202
# 0.165    193
# 0.135    189
# 0.145    182
# 0.130    169
# 0.120    169
# 0.170    160
# 0.100    145
# 0.110    135
# 0.115    133
# 0.180    131
# 0.090    124
# 0.105    114
# 0.185    103
# 0.190    103
# 0.095     91
# 0.195     78
# 0.080     76
# 0.085     74
# 0.200     68
# 0.075     61
# 0.070     47
# 0.205     45
# 0.065     39
# 0.215     31
# 0.060     26
# 0.055     25
# 0.210     23
# 0.050     18
# 0.220     17
# 0.040     13
# 0.225     13
# 0.045     11
# 0.230     10
# 0.030      6
# 0.035      6
# 0.235      6
# 0.025      5
# 0.240      4
# 0.250      3
# 0.020      2
# 0.015      2
# 0.000      2
# 0.010      1
# 0.515      1
# 1.130      1
# Name: count, dtype: int64
# height Subject Count: 51

# %%
# whole_weight 레이블 개수 확인 (숫자)
print("whole_weight label count:")
print(df['whole_weight'].value_counts(), "\n")
# whole_weight 레이블 개수 확인 (그래프)
plt.figure(figsize=(10, 4))
sns.countplot(data=df, x="whole_weight")
plt.xlabel("whole_weight")
plt.title("Abalone - whole_weight")
plt.show()
# whole_weight subject 개수 확인
whole_weight_subject_count = df['whole_weight'].nunique()
print("whole_weight Subject Count:", whole_weight_subject_count)
# Out:
# whole_weight label count:
# whole_weight
# 0.2225    8
# 1.1345    7
# 0.9700    7
# 0.4775    7
# 0.1960    7
#          ..
# 0.0475    1
# 1.8930    1
# 1.8725    1
# 2.1055    1
# 1.9485    1
# Name: count, Length: 2429, dtype: int64
# whole_weight Subject Count: 2429

# %%
# shucked_weight 레이블 개수 확인 (숫자)
print("shucked_weight label count:")
print(df['shucked_weight'].value_counts(), "\n")
# shucked_weight 레이블 개수 확인 (그래프)
plt.figure(figsize=(10, 4))
sns.countplot(data=df, x="shucked_weight")
plt.xlabel("shucked_weight")
plt.title("Abalone - shucked_weight")
plt.show()
# shucked_weight subject 개수 확인
shucked_weight_subject_count = df['shucked_weight'].nunique()
print("shucked_weight Subject Count:", shucked_weight_subject_count)
# Out:
# shucked_weight label count:
# shucked_weight
# 0.1750    11
# 0.2505    10
# 0.0970     9
# 0.0960     9
# 0.4190     9
#           ..
# 0.4175     1
# 0.1935     1
# 0.1790     1
# 0.1275     1
# 0.9455     1
# Name: count, Length: 1515, dtype: int64
# shucked_weight Subject Count: 1515

# %%
# viscera_weight 레이블 개수 확인 (숫자)
print("viscera_weight label count:")
print(df['viscera_weight'].value_counts(), "\n")
# viscera_weight 레이블 개수 확인 (그래프)
plt.figure(figsize=(10,4))
sns.countplot(data=df, x="viscera_weight")
plt.xlabel("viscera_weight")
plt.title("Abalone - viscera_weight")
plt.show()
# viscera_weight subject 개수 확인
viscera_weight_subject_count = df['viscera_weight'].nunique()
print("viscera_weight Subject Count:", viscera_weight_subject_count)
# Out:
# viscera_weight label count:
# viscera_weight
# 0.1715    15
# 0.1960    14
# 0.0575    13
# 0.0610    13
# 0.0370    13
#           ..
# 0.4270     1
# 0.4075     1
# 0.4920     1
# 0.4650     1
# 0.5260     1
# Name: count, Length: 880, dtype: int64
# viscera_weight Subject Count: 880

# %%
# shell_weight 레이블 개수 확인 (숫자)
print("shell_weight label count:")
print(df['shell_weight'].value_counts(), "\n")
# shell_weight 레이블 개수 확인 (그래프)
plt.figure(figsize=(10, 4))
sns.countplot(data=df, x="shell_weight")
plt.xlabel("shell_weight")
plt.title("Abalone - shell_weight")
plt.show()
# shell_weight subject 개수 확인
shell_weight_subject_count = df['shell_weight'].nunique()
print("shell_weight Subject Count:", shell_weight_subject_count)
# Out:
# shell_weight label count:
# shell_weight
# 0.2750    43
# 0.2500    42
# 0.2650    40
# 0.3150    40
# 0.1850    40
#           ..
# 0.0060     1
# 0.6460     1
# 0.5010     1
# 0.3295     1
# 0.0920     1
# Name: count, Length: 926, dtype: int64
# shell_weight Subject Count: 926

# %%
# rings 레이블 개수 확인 (숫자)
print("rings label count:")
print(df['rings'].value_counts(), "\n")
# rings 레이블 개수 확인 (그래프)
plt.figure(figsize=(10, 3))
sns.countplot(data=df, x="rings")
plt.xlabel("rings")
plt.title("Abalone - rings")
plt.show()
# rings subject 개수 확인
rings_subject_count = df['rings'].nunique()
print("rings Subject Count:", rings_subject_count)
# Out:
# rings label count:
# rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64
# rings Subject Count: 28

# %%
# 라벨 인코딩 (문자형 데이터로 라벨링이 되어 있는 컬럼 데이터들 라벨링 필요.)

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# LabelEncoder 객체 생성
label = LabelEncoder()

#LabelEncoder를 적용하여 변환
df['sex'] = label.fit_transform(df['sex'])

df
# Out:
#       sex  length  diameter  height  whole_weight  shucked_weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       viscera_weight  shell_weight  rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
# 라벨링 결과 확인
# sub_id 레이블 개수 확인 (그래프)
sns.countplot(data = df, x="sex")
plt.xlabel("sex")
plt.title("Abalone")
# Out:
# Text(0.5, 1.0, 'Abalone')

# %%
# 정규화 standard scaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 특성 데이터를 표준화
std_scaled_data = scaler.fit_transform(df)

print(std_scaled_data)
# Out:
# [[ 1.15198011 -0.57455813 -0.43214879 ... -0.72621157 -0.63821689
#    1.57154357]
#  [ 1.15198011 -1.44898585 -1.439929   ... -1.20522124 -1.21298732
#   -0.91001299]
#  [-1.28068972  0.05003309  0.12213032 ... -0.35668983 -0.20713907
#   -0.28962385]
#  ...
#  [ 1.15198011  0.6329849   0.67640943 ...  0.97541324  0.49695471
#   -0.28962385]
#  [-1.28068972  0.84118198  0.77718745 ...  0.73362741  0.41073914
#    0.02057072]
#  [ 1.15198011  1.54905203  1.48263359 ...  1.78744868  1.84048058
#    0.64095986]]

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# sex               0
# length            0
# diameter          0
# height            0
# whole_weight      0
# shucked_weight    0
# viscera_weight    0
# shell_weight      0
# rings             0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# sex               0
# length            0
# diameter          0
# height            0
# whole_weight      0
# shucked_weight    0
# viscera_weight    0
# shell_weight      0
# rings             0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
# StandardScaler 객체 생성
scaler = StandardScaler()

# 특성 데이터를 표준화
std_scaled_data = scaler.fit_transform(df)

print(std_scaled_data)

X=df.drop(['shell_weight', 'sex'], axis=1)

print(X.head(),"\n\n")

y=df['sex']

print(y.value_counts())
# Out:
# [[ 1.15198011 -0.57455813 -0.43214879 ... -0.72621157 -0.63821689
#    1.57154357]
#  [ 1.15198011 -1.44898585 -1.439929   ... -1.20522124 -1.21298732
#   -0.91001299]
#  [-1.28068972  0.05003309  0.12213032 ... -0.35668983 -0.20713907
#   -0.28962385]
#  ...
#  [ 1.15198011  0.6329849   0.67640943 ...  0.97541324  0.49695471
#   -0.28962385]
#  [-1.28068972  0.84118198  0.77718745 ...  0.73362741  0.41073914
#    0.02057072]
#  [ 1.15198011  1.54905203  1.48263359 ...  1.78744868  1.84048058
#    0.64095986]]
#    length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    rings
# ...

# %%
# One-Hot Encoding

# %%
y = pd.get_dummies(y).values
y
# Out:
# array([[False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        ...,
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True]])

# %%
# X,y 분류

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값
X_train
# Out:
#       length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 940    0.460     0.345   0.105        0.4490          0.1960          0.0945
# 2688   0.630     0.465   0.150        1.0270          0.5370          0.1880
# 1948   0.635     0.515   0.165        1.2290          0.5055          0.2975
# 713    0.355     0.265   0.085        0.2010          0.0690          0.0530
# 3743   0.705     0.555   0.195        1.7525          0.7105          0.4215
# ...      ...       ...     ...           ...             ...             ...
# 1033   0.650     0.525   0.185        1.6220          0.6645          0.3225
# 3264   0.655     0.500   0.140        1.1705          0.5405          0.3175
# 1653   0.595     0.450   0.145        0.9590          0.4630          0.2065
# 2607   0.625     0.490   0.165        1.1270          0.4770          0.2365
# 2732   0.410     0.325   0.110        0.3260          0.1325          0.0750
#
#       rings
# 940       7
# 2688      8
# ...

# %%
print(X_test.shape)
print(X_train.shape)
# Out:
# (1045, 7)
# (3132, 7)

# %%
y_train
# Out:
# array([[False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        ...,
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False]])

# %%
print(y_test.shape)
print(y_train.shape)
# Out:
# (1045, 3)
# (3132, 3)

# %%
#Defining the model 
#분류 예제

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam, Nadam

model = Sequential()

model.add(Dense(30,input_shape=(X_train.shape[1],),activation='relu'))
#input_shape: 입력 데이터의 모양을 지정한다. 첫 번째 레이어에서만 사용된다.
model.add(Dense(20,activation='relu'))
model.add(Dense(3,activation='softmax'))

#출력 유닛 수는 레이블 수에 맞게끔 변수를 맞춰 설정해줘야 함. 여기서는 3

model.compile(Adam(learning_rate=0.02),'categorical_crossentropy', metrics=['accuracy'])
# 이진 분류일 때, model.compile(Adam(lr=0.04),'bce',metrics=['accuracy']) 를 써야한다.

model.summary()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 30)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            63 │
# ...

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1) # 배열에서 최댓값을 가지는 원소의 인덱스를 반환하는 함수
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3722 - loss: 1.0998 - val_accuracy: 0.5292 - val_loss: 0.9014
# Epoch 2/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.5182 - loss: 0.9112 - val_accuracy: 0.5378 - val_loss: 0.8846
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.5216 - loss: 0.8852 - val_accuracy: 0.5234 - val_loss: 0.8869
# Epoch 4/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.5304 - loss: 0.8908 - val_accuracy: 0.5244 - val_loss: 0.8830
# Epoch 5/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.5356 - loss: 0.8874 - val_accuracy: 0.5483 - val_loss: 0.8693
# Epoch 6/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.5246 - loss: 0.8968 - val_accuracy: 0.5512 - val_loss: 0.8605
# Epoch 7/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.5342 - loss: 0.8727 - val_accuracy: 0.5426 - val_loss: 0.8752
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 훈련 손실(training loss)과 검증 손실(validation loss) 추출
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# 에포크(epoch) 범위 생성
epochs = range(1, len(loss) + 1)

# 훈련 손실(training loss)과 검증 손실(validation loss) 시각화
plt.plot(epochs, loss, 'y', label='Training loss')  # 훈련 손실을 노란색(yellow)으로 플롯
plt.plot(epochs, val_loss, 'r', label='Validation loss')  # 검증 손실을 빨간색(red)으로 플롯
plt.title('Training and validation loss')  # 그래프 제목 설정
plt.xlabel('Epochs')  # x축 레이블 설정
plt.ylabel('Loss')  # y축 레이블 설정
plt.legend()  # 범례(legend) 표시
plt.show()  # 그래프 출력

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# 모델의 정확도 출력

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class),"\n")
print(confusion_matrix(y_test_class,y_pred_class),"\n")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.63      0.52       316
#            1       0.72      0.75      0.74       359
#            2       0.41      0.26      0.32       370
#
#     accuracy                           0.54      1045
#    macro avg       0.53      0.55      0.53      1045
# weighted avg       0.53      0.54      0.52      1045
#
#
# [[198  32  86]
#  [ 39 271  49]
#  [202  73  95]]
